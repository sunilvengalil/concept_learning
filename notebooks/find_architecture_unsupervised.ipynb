# %% [markdown]
# <a href="https://colab.research.google.com/github/sunilvengalil/concept_learning/blob/master/notebooks/find_architecture_unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.14.0
from google.colab import drive
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/concept_learning/concept_learning
# Out:
# /content/gdrive/My Drive/concept_learning/concept_learning

# %%
# !git pull
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 9 (delta 7), reused 9 (delta 7), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/sunilvengalil/concept_learning
#    87a971a..2b7d0a8  master     -> origin/master
# Updating 87a971a..2b7d0a8
# Fast-forward
#  clearn/experiments/experiment.py                   |  6 +-
#  clearn/models/vae.py                               | 66 ++++++++++------------
#  .../find_architecture_unsupervised.py              |  7 ++-
#  3 files changed, 40 insertions(+), 39 deletions(-)

# %%
rm -rf  /content/gdrive/MyDrive/concept_learning/concept_learning/concept_learning_exp/find_architecture_unsup

# %%
import tensorflow as tf
from clearn.experiments.experiment import initialize_model_train_and_get_features, MODEL_TYPE_VAE_UNSUPERVISED
from clearn.config import ExperimentConfig

# %%
create_split = False
experiment_name = "find_architecture_unsup"
num_epochs = 50
num_cluster_config = ExperimentConfig.NUM_CLUSTERS_CONFIG_TWO_TIMES_ELBOW
run_id = 1
z_dim_range = [5,30,2]
train_val_data_iterator = None
root_path="/content/gdrive/MyDrive/concept_learning/concept_learning/concept_learning_exp"
tf.reset_default_graph()
# num_units_list = [[64, 128, 32],
#                   [64, 64, 32],
#                   [64, 32, 32],
#                   [32, 32, 32],
#                   [32, 16, 32],
#                   [16, 16, 32],
#                   [16,8,32],
#                   [8, 8, 32],
#                   [8, 4, 32],
#                   [4, 4, 32],
#                   ]
num_units_list = [[64, 32],
                  [32, 32],
                  [16, 32],
                  [8, 32],
                  [4, 32],
                  [2, 32],
                      ]
for num_units in num_units_list:
    for z_dim in range(z_dim_range[0], z_dim_range[1], z_dim_range[2]):
        train_val_data_iterator, exp_config, model = initialize_model_train_and_get_features(root_path=root_path,
                                                                                             experiment_name=experiment_name,
                                                                                             z_dim=z_dim,
                                                                                             batch_size=128,
                                                                                             run_id=run_id,
                                                                                             create_split=create_split,
                                                                                             num_epochs=num_epochs,
                                                                                             reconstruction_weight=1,
                                                                                             model_type=MODEL_TYPE_VAE_UNSUPERVISED,
                                                                                             num_units=num_units,
                                                                                             save_reconstructed_images=False,
                                                                                             split_name="Split_70_30",
                                                                                             train_val_data_iterator=train_val_data_iterator,
                                                                                             eval_interval_in_epochs=1,
                                                                                             model_save_interval=10,
                                                                                             num_val_samples=-1,
                                                                                             run_evaluation_during_training=True,
                                                                                             return_latent_vector=False,
                                                                                             write_predictions=False
                                                                                             )
        tf.reset_default_graph()
# Out:
# {'NUM_UNITS': [64, 32], 'ROOT_PATH': '/content/gdrive/MyDrive/concept_learning/concept_learning/concept_learning_exp', 'NUM_DECODER_LAYER': 3, 'Z_DIM': 5, 'BETA': 5, 'DATASET_NAME': 'mnist', 'MODEL_NAME': 'VAE', 'BATCH_SIZE': 128, 'SPLIT_NAME': 'Split_70_30', 'SUPERVISE_WEIGHT': 150, 'NUM_CLUSTER_CONFIG': None, 'CONFIDENCE_DECAY_FACTOR': 5, 'MANUAL_LABELS_CONFIG': 'USE_CLUSTER_CENTER', 'RECONSTRUCTION_WEIGHT': 1, 'ACTIVATION_HIDDEN_LAYER': 'RELU', 'ACTIVATION_OUTPUT_LAYER': 'SIGMOID', 'SAVE_RECONSTRUCTED_IMAGES': False, 'NUM_VAL_SAMPLES': -1, 'LEARNING_RATE': 0.001, 'MAX_CHECKPOINTS_TO_KEEP': 20, 'BETA1_ADAM': 0.9, 'RUN_EVALUATION_DURING_TRAINING': True, 'MODEL_SAVE_INTERVAL': 10, 'WRITE_PREDICTIONS': False, 'EVAL_INTERVAL_IN_EPOCHS': 1, 'RETURN_LATENT_VECTOR': False, 'SEED': 547, 'BUDGET': 1, 'CLUSTERING_ALG': 'K_MEANS', 'CONFIDENCE_DECAY_FUNCTION': 'EXPONENTIAL', 'DISTANCE_METRIC': 'EUCLIDEAN', 'RUN_ID': 1, 'ID': 1, 'name': 'find_architecture_unsup'}
# ...

# %%
drive.flush_and_unmount()
